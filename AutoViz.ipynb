# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from pylab import rcParams
rcParams['figure.figsize'] = 12,6

# to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

sns.set(style='darkgrid')
# %matplotlib inline

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fidanfatih/Diabetic-Patient-Readmission-Prediction/main/diabetic_data_cleaned.csv', index_col=0)
df
# Out:
#                   race  gender      age  time_in_hospital  num_lab_procedures  \
# 0            Caucasian  Female  [10-20)                 3                  59
# 1      AfricanAmerican  Female  [20-30)                 2                  11
# 2            Caucasian    Male  [30-40)                 2                  44
# 3            Caucasian    Male  [40-50)                 1                  51
# 4            Caucasian    Male  [50-60)                 3                  31
# ...                ...     ...      ...               ...                 ...
# 64390            Other    Male  [40-50)                13                  51
# 64391        Caucasian  Female  [70-80)                 9                  50
# 64392            Other  Female  [60-70)                 2                  46
# 64393        Caucasian  Female  [80-90)                 5                  76
# 64394        Caucasian    Male  [70-80)                 6                  13
#
#        num_procedures  num_medications  number_outpatient  number_emergency  \
# 0                   0               18                  0                 0
# 1                   5               13                  2                 0
# 2                   1               16                  0                 0
# 3                   0                8                  0                 0
# 4                   6               16                  0                 0
# ...               ...              ...                ...               ...
# 64390               2               13                  0                 0
# 64391               2               33                  0                 0
# 64392               6               17                  1                 1
# 64393               1               22                  0                 1
# 64394               3                3                  0                 0
#
#        number_inpatient  ... miglitol  troglitazone tolazamide insulin  \
# 0                     0  ...       No            No         No      Up
# 1                     1  ...       No            No         No      No
# 2                     0  ...       No            No         No      Up
# 3                     0  ...       No            No         No  Steady
# 4                     0  ...       No            No         No  Steady
# ...                 ...  ...      ...           ...        ...     ...
# 64390                 0  ...       No            No         No    Down
# 64391                 0  ...       No            No         No  Steady
# 64392                 1  ...       No            No         No  Steady
# 64393                 0  ...       No            No         No      Up
# 64394                 0  ...       No            No         No      No
#
#       glyburide-metformin glipizide-metformin metformin-pioglitazone change  \
# 0                      No                  No                     No     Ch
# 1                      No                  No                     No     No
# 2                      No                  No                     No     Ch
# 3                      No                  No                     No     Ch
# 4                      No                  No                     No     No
# ...                   ...                 ...                    ...    ...
# 64390                  No                  No                     No     Ch
# 64391                  No                  No                     No     Ch
# 64392                  No                  No                     No     No
# 64393                  No                  No                     No     Ch
# 64394                  No                  No                     No     No
#
#       diabetesMed readmitted
# 0             Yes        YES
# 1             Yes         NO
# 2             Yes         NO
# 3             Yes         NO
# 4             Yes        YES
# ...           ...        ...
# 64390         Yes         NO
# 64391         Yes        YES
# 64392         Yes        YES
# 64393         Yes         NO
# 64394          No         NO
#
# [64395 rows x 35 columns]

# %%
df.shape
# Out:
# (64360, 35)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

sep = ','
dft = AV.AutoViz(filename="",sep=sep, depVar='readmitted', dfte=df, header=0, verbose=2, 
                 lowess=False, chart_format='svg', max_rows_analyzed=150000, max_cols_analyzed=30)
# Out:
# Shape of your Data Set: (64360, 35)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
# Data Set Shape: 64360 rows, 34 cols
# Too many columns to print
#     Numeric Columns: []
#     Integer-Categorical Columns: ['time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_inpatient', 'number_diagnoses']
#     String-Categorical Columns: ['race', 'age', 'diag_1', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'insulin', 'glyburide-metformin']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['gender', 'tolbutamide', 'troglitazone', 'tolazamide', 'glipizide-metformin', 'metformin-pioglitazone', 'change', 'diabetesMed']
#     Numeric-Boolean Columns: ['number_emergency']
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: []
#     Columns that will not be considered in modeling: []
#     34 Predictors classified...
#         This does not include the Target column(s)
#         No variables removed since no ID or low-information variables found in data set
# Number of variables = 34 exceeds limit, finding top 30 variables through XGBoost
#     No categorical feature reduction done. All 27 Categorical vars selected
#     Removing correlated variables from 7 numerics using SULO method
# Selecting all (7) variables since none of them are highly correlated...
#     Adding 27 categorical variables to reduced numeric variables  of 7
# ############## F E A T U R E   S E L E C T I O N  ####################
# Current number of predictors = 34
#     Finding Important Features using Boosted Trees algorithm...
#         using 34 variables...
#         using 27 variables...
#         using 20 variables...
#         using 13 variables...
#         using 6 variables...
# Found 21 important features
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
# Data Set Shape: 64360 rows, 21 cols
# Data Set columns info:
# * number_inpatient: 0 nulls, 3 unique vals, most common: {0: 57746, 1: 5262}
# * diabetesMed: 0 nulls, 2 unique vals, most common: {'Yes': 48400, 'No': 15960}
# * number_outpatient: 0 nulls, 4 unique vals, most common: {0: 57229, 1: 4316}
# * number_emergency: 0 nulls, 2 unique vals, most common: {0: 60803, 1: 3557}
# * number_diagnoses: 0 nulls, 12 unique vals, most common: {9: 28263, 5: 7971}
# * rosiglitazone: 0 nulls, 4 unique vals, most common: {'No': 60134, 'Steady': 4047}
# * acarbose: 0 nulls, 3 unique vals, most common: {'No': 64185, 'Steady': 165}
# * age: 0 nulls, 10 unique vals, most common: {'[70-80)': 16428, '[60-70)': 14374}
# * glyburide-metformin: 0 nulls, 4 unique vals, most common: {'No': 63915, 'Steady': 436}
# * num_procedures: 0 nulls, 7 unique vals, most common: {0: 28557, 1: 13082}
# * metformin: 0 nulls, 4 unique vals, most common: {'No': 50845, 'Steady': 12395}
# * insulin: 0 nulls, 4 unique vals, most common: {'No': 32176, 'Steady': 19705}
# * diag_1: 0 nulls, 9 unique vals, most common: {'Circulatory': 19524, 'Other': 11032}
# * repaglinide: 0 nulls, 4 unique vals, most common: {'No': 63514, 'Steady': 755}
# * race: 0 nulls, 5 unique vals, most common: {'Caucasian': 49348, 'AfricanAmerican': 12022}
# * change: 0 nulls, 2 unique vals, most common: {'No': 36125, 'Ch': 28235}
# * glipizide: 0 nulls, 4 unique vals, most common: {'No': 56233, 'Steady': 7299}
# * pioglitazone: 0 nulls, 4 unique vals, most common: {'No': 59614, 'Steady': 4516}
# * miglitol: 0 nulls, 4 unique vals, most common: {'No': 64341, 'Steady': 17}
# * tolbutamide: 0 nulls, 2 unique vals, most common: {'No': 64342, 'Steady': 18}
# * tolazamide: 0 nulls, 2 unique vals, most common: {'No': 64331, 'Steady': 29}
# --------------------------------------------------------------------
#     Numeric Columns: []
#     Integer-Categorical Columns: ['number_inpatient', 'number_outpatient', 'number_diagnoses', 'num_procedures']
#     String-Categorical Columns: ['rosiglitazone', 'acarbose', 'age', 'glyburide-metformin', 'metformin', 'insulin', 'diag_1', 'repaglinide', 'race', 'glipizide', 'pioglitazone', 'miglitol']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['diabetesMed', 'change', 'tolbutamide', 'tolazamide']
#     Numeric-Boolean Columns: ['number_emergency']
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: []
#     Columns that will not be considered in modeling: []
#     21 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data
#     List of variables removed: []
# Total Number of Scatter Plots = 10
# Time to run AutoViz (in seconds) = 73.906
